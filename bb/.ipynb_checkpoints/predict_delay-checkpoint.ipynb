# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# read 데이터
dly = pd.read_csv('AFSNT_DLY.CSV', encoding="cp949")
dly.head()
# Out:
#    SDT_YY  SDT_MM  SDT_DD SDT_DY   ARP   ODP FLO    FLT AOD    STT  DLY  \
# 0    2019       9      16      월  ARP1  ARP3   L  L1702   A   9:05  NaN
# 1    2019       9      16      월  ARP3  ARP1   L  L1702   D   7:55  NaN
# 2    2019       9      16      월  ARP1  ARP3   L  L1720   A  14:40  NaN
# 3    2019       9      16      월  ARP3  ARP1   L  L1720   D  13:30  NaN
# 4    2019       9      16      월  ARP4  ARP3   L  L1808   A  20:10  NaN
#
#    DLY_RATE
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
dly.head()
# Out:
#    SDT_YY  SDT_MM  SDT_DD SDT_DY   ARP   ODP FLO    FLT AOD    STT  DLY  \
# 0    2019       9      16      월  ARP1  ARP3   L  L1702   A   9:05  NaN
# 1    2019       9      16      월  ARP3  ARP1   L  L1702   D   7:55  NaN
# 2    2019       9      16      월  ARP1  ARP3   L  L1720   A  14:40  NaN
# 3    2019       9      16      월  ARP3  ARP1   L  L1720   D  13:30  NaN
# 4    2019       9      16      월  ARP4  ARP3   L  L1808   A  20:10  NaN
#
#    DLY_RATE
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
dly['hour'] = pd.to_datetime(dly['STT'],format= '%H:%M').dt.hour

# %%
import urllib
import json
import pandas as pd
import dateutil.parser
#날씨데이터 json 읽어오는 함수

#나중에 9월 1일을 9월 16일로 바꾼 후 실행..
#(읽어오는거 확인용으로 9월 1일 부터...)
def readJSON(area):
    
    request = urllib.request.urlopen('https://api.aerisapi.com/forecasts/'+area+',korea?from=09/16/2019&format=json&filter=1hr&limit=999&client_id=gHOhinKWCL1fwDUpI1Ec7&client_secret=TRamBTyXpORXcmDKVqc2S4i4mnCjVxxHMt6cllui')
    response = request.read()
    data= json.loads(response)


    if data['success']:
        return data

    else:
        print("An error occurred: %s" % (data['error']['description']))
        return ""
        request.close()

# %%
data=readJSON("jeju")
data
# Out:
# {'success': True,
#  'error': None,
#  'response': [{'loc': {'long': 126.522, 'lat': 33.51},
#    'interval': '1hr',
#    'periods': [{'timestamp': 1568559600,
#      'validTime': '2019-09-16T00:00:00+09:00',
#      'dateTimeISO': '2019-09-16T00:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 71,
#      'minTempC': 22,
#      'minTempF': 71,
#      'avgTempC': 22,
#      'avgTempF': 71,
#      'tempC': 22,
#      'tempF': 71,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 82,
#      'minHumidity': 82,
#      'humidity': 82,
#      'uvi': 0,
#      'pressureMB': 1012,
#      'pressureIN': 29.88,
#      'sky': 4,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 22,
#      'feelslikeF': 72,
#      'minFeelslikeC': 22,
#      'minFeelslikeF': 72,
#      'maxFeelslikeC': 22,
#      'maxFeelslikeF': 72,
#      'avgFeelslikeC': 22,
#      'avgFeelslikeF': 72,
#      'dewpointC': 19,
#      'dewpointF': 66,
#      'maxDewpointC': 19,
#      'maxDewpointF': 66,
#      'minDewpointC': 19,
#      'minDewpointF': 66,
#      'avgDewpointC': 19,
#      'avgDewpointF': 66,
#      'windDirDEG': 333,
#      'windDir': 'NNW',
#      'windDirMaxDEG': 333,
#      'windDirMax': 'NNW',
#      'windDirMinDEG': 333,
#      'windDirMin': 'NNW',
#      'windGustKTS': 3,
#      'windGustKPH': 5,
#      'windGustMPH': 3,
#      'windSpeedKTS': 3,
#      'windSpeedKPH': 5,
#      'windSpeedMPH': 3,
#      'windSpeedMaxKTS': 3,
#      'windSpeedMaxKPH': 5,
#      'windSpeedMaxMPH': 3,
#      'windSpeedMinKTS': 3,
#      'windSpeedMinKPH': 5,
#      'windSpeedMinMPH': 3,
#      'windDir80mDEG': 332,
#      'windDir80m': 'NNW',
#      'windDirMax80mDEG': 333,
#      'windDirMax80m': 'NNW',
#      'windDirMin80mDEG': 333,
#      'windDirMin80m': 'NNW',
#      'windGust80mKTS': 3,
#      'windGust80mKPH': 5,
#      'windGust80mMPH': 3,
#      'windSpeed80mKTS': 3,
#      'windSpeed80mKPH': 5,
#      'windSpeed80mMPH': 3,
#      'windSpeedMax80mKTS': 3,
#      'windSpeedMax80mKPH': 5,
#      'windSpeedMax80mMPH': 3,
#      'windSpeedMin80mKTS': 3,
#      'windSpeedMin80mKPH': 5,
#      'windSpeedMin80mMPH': 3,
#      'weather': 'Clear',
#      'weatherCoded': [],
#      'weatherPrimary': 'Clear',
#      'weatherPrimaryCoded': '::CL',
#      'cloudsCoded': 'CL',
#      'icon': 'clearn.png',
#      'isDay': False},
#     {'timestamp': 1568563200,
#      'validTime': '2019-09-16T01:00:00+09:00',
#      'dateTimeISO': '2019-09-16T01:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 71,
#      'minTempC': 22,
#      'minTempF': 71,
#      'avgTempC': 22,
#      'avgTempF': 71,
#      'tempC': 22,
#      'tempF': 71,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 82,
#      'minHumidity': 82,
#      'humidity': 82,
#      'uvi': 0,
#      'pressureMB': 1012,
#      'pressureIN': 29.88,
#      'sky': 17,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 22,
#      'feelslikeF': 72,
#      'minFeelslikeC': 22,
#      'minFeelslikeF': 72,
#      'maxFeelslikeC': 22,
#      'maxFeelslikeF': 72,
#      'avgFeelslikeC': 22,
#      'avgFeelslikeF': 72,
#      'dewpointC': 19,
#      'dewpointF': 66,
#      'maxDewpointC': 19,
#      'maxDewpointF': 66,
#      'minDewpointC': 19,
#      'minDewpointF': 66,
#      'avgDewpointC': 19,
#      'avgDewpointF': 66,
#      'windDirDEG': 73,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 73,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 73,
#      'windDirMin': 'ENE',
#      'windGustKTS': 2,
#      'windGustKPH': 5,
#      'windGustMPH': 3,
#      'windSpeedKTS': 2,
#      'windSpeedKPH': 5,
#      'windSpeedMPH': 3,
#      'windSpeedMaxKTS': 2,
#      'windSpeedMaxKPH': 5,
#      'windSpeedMaxMPH': 3,
#      'windSpeedMinKTS': 2,
#      'windSpeedMinKPH': 5,
#      'windSpeedMinMPH': 3,
#      'windDir80mDEG': 73,
#      'windDir80m': 'ENE',
#      'windDirMax80mDEG': 73,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 73,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': 3,
#      'windGust80mKPH': 5,
#      'windGust80mMPH': 3,
#      'windSpeed80mKTS': 3,
#      'windSpeed80mKPH': 5,
#      'windSpeed80mMPH': 3,
#      'windSpeedMax80mKTS': 3,
#      'windSpeedMax80mKPH': 5,
#      'windSpeedMax80mMPH': 3,
#      'windSpeedMin80mKTS': 3,
#      'windSpeedMin80mKPH': 5,
#      'windSpeedMin80mMPH': 3,
#      'weather': 'Mostly Clear',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Clear',
#      'weatherPrimaryCoded': '::FW',
#      'cloudsCoded': 'FW',
#      'icon': 'pcloudyn.png',
#      'isDay': False},
#     {'timestamp': 1568566800,
#      'validTime': '2019-09-16T02:00:00+09:00',
#      'dateTimeISO': '2019-09-16T02:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 71,
#      'minTempC': 22,
#      'minTempF': 71,
#      'avgTempC': 22,
#      'avgTempF': 71,
#      'tempC': 22,
#      'tempF': 71,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 82,
#      'minHumidity': 82,
#      'humidity': 82,
#      'uvi': 0,
#      'pressureMB': 1012,
#      'pressureIN': 29.88,
#      'sky': 30,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 22,
#      'feelslikeF': 72,
#      'minFeelslikeC': 22,
#      'minFeelslikeF': 72,
#      'maxFeelslikeC': 22,
#      'maxFeelslikeF': 72,
#      'avgFeelslikeC': 22,
#      'avgFeelslikeF': 72,
#      'dewpointC': 19,
#      'dewpointF': 66,
#      'maxDewpointC': 19,
#      'maxDewpointF': 66,
#      'minDewpointC': 19,
#      'minDewpointF': 66,
#      'avgDewpointC': 19,
#      'avgDewpointF': 66,
#      'windDirDEG': 73,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 73,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 73,
#      'windDirMin': 'ENE',
#      'windGustKTS': 2,
#      'windGustKPH': 4,
#      'windGustMPH': 3,
#      'windSpeedKTS': 2,
#      'windSpeedKPH': 4,
#      'windSpeedMPH': 3,
#      'windSpeedMaxKTS': 2,
#      'windSpeedMaxKPH': 4,
#      'windSpeedMaxMPH': 3,
#      'windSpeedMinKTS': 2,
#      'windSpeedMinKPH': 4,
#      'windSpeedMinMPH': 3,
#      'windDir80mDEG': 73,
#      'windDir80m': 'ENE',
#      'windDirMax80mDEG': 73,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 73,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': 3,
#      'windGust80mKPH': 5,
#      'windGust80mMPH': 3,
#      'windSpeed80mKTS': 3,
#      'windSpeed80mKPH': 5,
#      'windSpeed80mMPH': 3,
#      'windSpeedMax80mKTS': 3,
#      'windSpeedMax80mKPH': 5,
#      'windSpeedMax80mMPH': 3,
#      'windSpeedMin80mKTS': 3,
#      'windSpeedMin80mKPH': 5,
#      'windSpeedMin80mMPH': 3,
#      'weather': 'Mostly Clear',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Clear',
#      'weatherPrimaryCoded': '::FW',
#      'cloudsCoded': 'FW',
#      'icon': 'pcloudyn.png',
#      'isDay': False},
#     {'timestamp': 1568570400,
#      'validTime': '2019-09-16T03:00:00+09:00',
#      'dateTimeISO': '2019-09-16T03:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 71,
#      'minTempC': 22,
#      'minTempF': 71,
#      'avgTempC': 22,
#      'avgTempF': 71,
#      'tempC': 22,
#      'tempF': 71,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 82,
#      'minHumidity': 82,
#      'humidity': 82,
#      'uvi': 0,
#      'pressureMB': 1012,
#      'pressureIN': 29.88,
#      'sky': 43,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 22,
#      'feelslikeF': 72,
#      'minFeelslikeC': 22,
#      'minFeelslikeF': 72,
#      'maxFeelslikeC': 22,
#      'maxFeelslikeF': 72,
#      'avgFeelslikeC': 22,
#      'avgFeelslikeF': 72,
#      'dewpointC': 19,
#      'dewpointF': 66,
#      'maxDewpointC': 19,
#      'maxDewpointF': 66,
#      'minDewpointC': 19,
#      'minDewpointF': 66,
#      'avgDewpointC': 19,
#      'avgDewpointF': 66,
#      'windDirDEG': 73,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 73,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 73,
#      'windDirMin': 'ENE',
#      'windGustKTS': 2,
#      'windGustKPH': 4,
#      'windGustMPH': 2,
#      'windSpeedKTS': 2,
#      'windSpeedKPH': 4,
#      'windSpeedMPH': 2,
#      'windSpeedMaxKTS': 2,
#      'windSpeedMaxKPH': 4,
#      'windSpeedMaxMPH': 2,
#      'windSpeedMinKTS': 2,
#      'windSpeedMinKPH': 4,
#      'windSpeedMinMPH': 2,
#      'windDir80mDEG': 73,
#      'windDir80m': 'ENE',
#      'windDirMax80mDEG': 73,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 73,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': 3,
#      'windGust80mKPH': 6,
#      'windGust80mMPH': 3,
#      'windSpeed80mKTS': 3,
#      'windSpeed80mKPH': 6,
#      'windSpeed80mMPH': 3,
#      'windSpeedMax80mKTS': 3,
#      'windSpeedMax80mKPH': 6,
#      'windSpeedMax80mMPH': 3,
#      'windSpeedMin80mKTS': 3,
#      'windSpeedMin80mKPH': 6,
#      'windSpeedMin80mMPH': 3,
#      'weather': 'Partly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Partly Cloudy',
#      'weatherPrimaryCoded': '::SC',
#      'cloudsCoded': 'SC',
#      'icon': 'pcloudyn.png',
#      'isDay': False},
#     {'timestamp': 1568574000,
#      'validTime': '2019-09-16T04:00:00+09:00',
#      'dateTimeISO': '2019-09-16T04:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 71,
#      'minTempC': 22,
#      'minTempF': 71,
#      'avgTempC': 22,
#      'avgTempF': 71,
#      'tempC': 22,
#      'tempF': 71,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 82,
#      'minHumidity': 82,
#      'humidity': 82,
#      'uvi': 0,
#      'pressureMB': 1012,
#      'pressureIN': 29.88,
#      'sky': 40,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 22,
#      'feelslikeF': 72,
#      'minFeelslikeC': 22,
#      'minFeelslikeF': 72,
#      'maxFeelslikeC': 22,
#      'maxFeelslikeF': 72,
#      'avgFeelslikeC': 22,
#      'avgFeelslikeF': 72,
#      'dewpointC': 19,
#      'dewpointF': 65,
#      'maxDewpointC': 19,
#      'maxDewpointF': 65,
#      'minDewpointC': 19,
#      'minDewpointF': 65,
#      'avgDewpointC': 19,
#      'avgDewpointF': 65,
#      'windDirDEG': 112,
#      'windDir': 'ESE',
#      'windDirMaxDEG': 112,
#      'windDirMax': 'ESE',
#      'windDirMinDEG': 112,
#      'windDirMin': 'ESE',
#      'windGustKTS': 3,
#      'windGustKPH': 6,
#      'windGustMPH': 4,
#      'windSpeedKTS': 3,
#      'windSpeedKPH': 6,
#      'windSpeedMPH': 4,
#      'windSpeedMaxKTS': 3,
#      'windSpeedMaxKPH': 6,
#      'windSpeedMaxMPH': 4,
#      'windSpeedMinKTS': 3,
#      'windSpeedMinKPH': 6,
#      'windSpeedMinMPH': 4,
#      'windDir80mDEG': 108,
#      'windDir80m': 'ESE',
#      'windDirMax80mDEG': 112,
#      'windDirMax80m': 'ESE',
#      'windDirMin80mDEG': 112,
#      'windDirMin80m': 'ESE',
#      'windGust80mKTS': 4,
#      'windGust80mKPH': 8,
#      'windGust80mMPH': 5,
#      'windSpeed80mKTS': 4,
#      'windSpeed80mKPH': 8,
#      'windSpeed80mMPH': 5,
#      'windSpeedMax80mKTS': 4,
#      'windSpeedMax80mKPH': 8,
#      'windSpeedMax80mMPH': 5,
#      'windSpeedMin80mKTS': 4,
#      'windSpeedMin80mKPH': 8,
#      'windSpeedMin80mMPH': 5,
#      'weather': 'Partly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Partly Cloudy',
#      'weatherPrimaryCoded': '::SC',
#      'cloudsCoded': 'SC',
#      'icon': 'pcloudyn.png',
#      'isDay': False},
#     {'timestamp': 1568577600,
#      'validTime': '2019-09-16T05:00:00+09:00',
#      'dateTimeISO': '2019-09-16T05:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 71,
#      'minTempC': 22,
#      'minTempF': 71,
#      'avgTempC': 22,
#      'avgTempF': 71,
#      'tempC': 22,
#      'tempF': 71,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 82,
#      'minHumidity': 82,
#      'humidity': 82,
#      'uvi': 0,
#      'pressureMB': 1012,
#      'pressureIN': 29.88,
#      'sky': 36,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 22,
#      'feelslikeF': 72,
#      'minFeelslikeC': 22,
#      'minFeelslikeF': 72,
#      'maxFeelslikeC': 22,
#      'maxFeelslikeF': 72,
#      'avgFeelslikeC': 22,
#      'avgFeelslikeF': 72,
#      'dewpointC': 19,
#      'dewpointF': 65,
#      'maxDewpointC': 19,
#      'maxDewpointF': 65,
#      'minDewpointC': 19,
#      'minDewpointF': 65,
#      'avgDewpointC': 19,
#      'avgDewpointF': 65,
#      'windDirDEG': 112,
#      'windDir': 'ESE',
#      'windDirMaxDEG': 112,
#      'windDirMax': 'ESE',
#      'windDirMinDEG': 112,
#      'windDirMin': 'ESE',
#      'windGustKTS': 4,
#      'windGustKPH': 8,
#      'windGustMPH': 5,
#      'windSpeedKTS': 4,
#      'windSpeedKPH': 8,
#      'windSpeedMPH': 5,
#      'windSpeedMaxKTS': 4,
#      'windSpeedMaxKPH': 8,
#      'windSpeedMaxMPH': 5,
#      'windSpeedMinKTS': 4,
#      'windSpeedMinKPH': 8,
#      'windSpeedMinMPH': 5,
#      'windDir80mDEG': 108,
#      'windDir80m': 'ESE',
#      'windDirMax80mDEG': 112,
#      'windDirMax80m': 'ESE',
#      'windDirMin80mDEG': 112,
#      'windDirMin80m': 'ESE',
#      'windGust80mKTS': 6,
#      'windGust80mKPH': 11,
#      'windGust80mMPH': 7,
#      'windSpeed80mKTS': 6,
#      'windSpeed80mKPH': 11,
#      'windSpeed80mMPH': 7,
#      'windSpeedMax80mKTS': 6,
#      'windSpeedMax80mKPH': 11,
#      'windSpeedMax80mMPH': 7,
#      'windSpeedMin80mKTS': 6,
#      'windSpeedMin80mKPH': 11,
#      'windSpeedMin80mMPH': 7,
#      'weather': 'Partly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Partly Cloudy',
#      'weatherPrimaryCoded': '::SC',
#      'cloudsCoded': 'SC',
#      'icon': 'pcloudyn.png',
#      'isDay': False},
#     {'timestamp': 1568581200,
#      'validTime': '2019-09-16T06:00:00+09:00',
#      'dateTimeISO': '2019-09-16T06:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 71,
#      'minTempC': 22,
#      'minTempF': 71,
#      'avgTempC': 22,
#      'avgTempF': 71,
#      'tempC': 22,
#      'tempF': 71,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 82,
#      'minHumidity': 82,
#      'humidity': 82,
#      'uvi': 0,
#      'pressureMB': 1012,
#      'pressureIN': 29.88,
#      'sky': 33,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 22,
#      'feelslikeF': 72,
#      'minFeelslikeC': 22,
#      'minFeelslikeF': 72,
#      'maxFeelslikeC': 22,
#      'maxFeelslikeF': 72,
#      'avgFeelslikeC': 22,
#      'avgFeelslikeF': 72,
#      'dewpointC': 19,
#      'dewpointF': 65,
#      'maxDewpointC': 19,
#      'maxDewpointF': 65,
#      'minDewpointC': 19,
#      'minDewpointF': 65,
#      'avgDewpointC': 19,
#      'avgDewpointF': 65,
#      'windDirDEG': 112,
#      'windDir': 'ESE',
#      'windDirMaxDEG': 112,
#      'windDirMax': 'ESE',
#      'windDirMinDEG': 112,
#      'windDirMin': 'ESE',
#      'windGustKTS': 5,
#      'windGustKPH': 9,
#      'windGustMPH': 6,
#      'windSpeedKTS': 5,
#      'windSpeedKPH': 9,
#      'windSpeedMPH': 6,
#      'windSpeedMaxKTS': 5,
#      'windSpeedMaxKPH': 9,
#      'windSpeedMaxMPH': 6,
#      'windSpeedMinKTS': 5,
#      'windSpeedMinKPH': 9,
#      'windSpeedMinMPH': 6,
#      'windDir80mDEG': 108,
#      'windDir80m': 'ESE',
#      'windDirMax80mDEG': 112,
#      'windDirMax80m': 'ESE',
#      'windDirMin80mDEG': 112,
#      'windDirMin80m': 'ESE',
#      'windGust80mKTS': 7,
#      'windGust80mKPH': 14,
#      'windGust80mMPH': 9,
#      'windSpeed80mKTS': 7,
#      'windSpeed80mKPH': 14,
#      'windSpeed80mMPH': 9,
#      'windSpeedMax80mKTS': 7,
#      'windSpeedMax80mKPH': 14,
#      'windSpeedMax80mMPH': 9,
#      'windSpeedMin80mKTS': 7,
#      'windSpeedMin80mKPH': 14,
#      'windSpeedMin80mMPH': 9,
#      'weather': 'Partly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Partly Cloudy',
#      'weatherPrimaryCoded': '::SC',
#      'cloudsCoded': 'SC',
#      'icon': 'pcloudyn.png',
#      'isDay': False},
#     {'timestamp': 1568584800,
#      'validTime': '2019-09-16T07:00:00+09:00',
#      'dateTimeISO': '2019-09-16T07:00:00+09:00',
#      'maxTempC': 23,
#      'maxTempF': 73,
#      'minTempC': 23,
#      'minTempF': 73,
#      'avgTempC': 23,
#      'avgTempF': 73,
#      'tempC': 23,
#      'tempF': 73,
#      'pop': 0,
#      'precipMM': 0.01,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 83,
#      'minHumidity': 83,
#      'humidity': 83,
#      'uvi': 0,
#      'pressureMB': 1013,
#      'pressureIN': 29.91,
#      'sky': 29,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 23,
#      'feelslikeF': 73,
#      'minFeelslikeC': 23,
#      'minFeelslikeF': 73,
#      'maxFeelslikeC': 23,
#      'maxFeelslikeF': 73,
#      'avgFeelslikeC': 23,
#      'avgFeelslikeF': 73,
#      'dewpointC': 20,
#      'dewpointF': 67,
#      'maxDewpointC': 20,
#      'maxDewpointF': 67,
#      'minDewpointC': 20,
#      'minDewpointF': 67,
#      'avgDewpointC': 20,
#      'avgDewpointF': 67,
#      'windDirDEG': 87,
#      'windDir': 'E',
#      'windDirMaxDEG': 87,
#      'windDirMax': 'E',
#      'windDirMinDEG': 87,
#      'windDirMin': 'E',
#      'windGustKTS': 7,
#      'windGustKPH': 13,
#      'windGustMPH': 8,
#      'windSpeedKTS': 7,
#      'windSpeedKPH': 13,
#      'windSpeedMPH': 8,
#      'windSpeedMaxKTS': 7,
#      'windSpeedMaxKPH': 13,
#      'windSpeedMaxMPH': 8,
#      'windSpeedMinKTS': 7,
#      'windSpeedMinKPH': 13,
#      'windSpeedMinMPH': 8,
#      'windDir80mDEG': 91,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 87,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 87,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 9,
#      'windGust80mKPH': 18,
#      'windGust80mMPH': 11,
#      'windSpeed80mKTS': 9,
#      'windSpeed80mKPH': 18,
#      'windSpeed80mMPH': 11,
#      'windSpeedMax80mKTS': 9,
#      'windSpeedMax80mKPH': 18,
#      'windSpeedMax80mMPH': 11,
#      'windSpeedMin80mKTS': 9,
#      'windSpeedMin80mKPH': 18,
#      'windSpeedMin80mMPH': 11,
#      'weather': 'Mostly Sunny',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Sunny',
#      'weatherPrimaryCoded': '::FW',
#      'cloudsCoded': 'FW',
#      'icon': 'pcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568588400,
#      'validTime': '2019-09-16T08:00:00+09:00',
#      'dateTimeISO': '2019-09-16T08:00:00+09:00',
#      'maxTempC': 23,
#      'maxTempF': 74,
#      'minTempC': 23,
#      'minTempF': 74,
#      'avgTempC': 23,
#      'avgTempF': 74,
#      'tempC': 23,
#      'tempF': 74,
#      'pop': 0,
#      'precipMM': 0.01,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 84,
#      'minHumidity': 84,
#      'humidity': 84,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 26,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 75,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 75,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 75,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 75,
#      'dewpointC': 21,
#      'dewpointF': 69,
#      'maxDewpointC': 21,
#      'maxDewpointF': 69,
#      'minDewpointC': 21,
#      'minDewpointF': 69,
#      'avgDewpointC': 21,
#      'avgDewpointF': 69,
#      'windDirDEG': 87,
#      'windDir': 'E',
#      'windDirMaxDEG': 87,
#      'windDirMax': 'E',
#      'windDirMinDEG': 87,
#      'windDirMin': 'E',
#      'windGustKTS': 9,
#      'windGustKPH': 16,
#      'windGustMPH': 10,
#      'windSpeedKTS': 9,
#      'windSpeedKPH': 16,
#      'windSpeedMPH': 10,
#      'windSpeedMaxKTS': 9,
#      'windSpeedMaxKPH': 16,
#      'windSpeedMaxMPH': 10,
#      'windSpeedMinKTS': 9,
#      'windSpeedMinKPH': 16,
#      'windSpeedMinMPH': 10,
#      'windDir80mDEG': 91,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 87,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 87,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 11,
#      'windGust80mKPH': 21,
#      'windGust80mMPH': 13,
#      'windSpeed80mKTS': 11,
#      'windSpeed80mKPH': 21,
#      'windSpeed80mMPH': 13,
#      'windSpeedMax80mKTS': 11,
#      'windSpeedMax80mKPH': 21,
#      'windSpeedMax80mMPH': 13,
#      'windSpeedMin80mKTS': 11,
#      'windSpeedMin80mKPH': 21,
#      'windSpeedMin80mMPH': 13,
#      'weather': 'Mostly Sunny',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Sunny',
#      'weatherPrimaryCoded': '::FW',
#      'cloudsCoded': 'FW',
#      'icon': 'pcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568592000,
#      'validTime': '2019-09-16T09:00:00+09:00',
#      'dateTimeISO': '2019-09-16T09:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 75,
#      'minTempC': 24,
#      'minTempF': 75,
#      'avgTempC': 24,
#      'avgTempF': 75,
#      'tempC': 24,
#      'tempF': 75,
#      'pop': 0,
#      'precipMM': 0.01,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 86,
#      'minHumidity': 86,
#      'humidity': 86,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 22,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 25,
#      'feelslikeF': 76,
#      'minFeelslikeC': 25,
#      'minFeelslikeF': 76,
#      'maxFeelslikeC': 25,
#      'maxFeelslikeF': 76,
#      'avgFeelslikeC': 25,
#      'avgFeelslikeF': 76,
#      'dewpointC': 21,
#      'dewpointF': 71,
#      'maxDewpointC': 21,
#      'maxDewpointF': 71,
#      'minDewpointC': 21,
#      'minDewpointF': 71,
#      'avgDewpointC': 21,
#      'avgDewpointF': 71,
#      'windDirDEG': 87,
#      'windDir': 'E',
#      'windDirMaxDEG': 87,
#      'windDirMax': 'E',
#      'windDirMinDEG': 87,
#      'windDirMin': 'E',
#      'windGustKTS': 11,
#      'windGustKPH': 20,
#      'windGustMPH': 12,
#      'windSpeedKTS': 11,
#      'windSpeedKPH': 20,
#      'windSpeedMPH': 12,
#      'windSpeedMaxKTS': 11,
#      'windSpeedMaxKPH': 20,
#      'windSpeedMaxMPH': 12,
#      'windSpeedMinKTS': 11,
#      'windSpeedMinKPH': 20,
#      'windSpeedMinMPH': 12,
#      'windDir80mDEG': 91,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 87,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 87,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 13,
#      'windGust80mKPH': 25,
#      'windGust80mMPH': 16,
#      'windSpeed80mKTS': 13,
#      'windSpeed80mKPH': 25,
#      'windSpeed80mMPH': 16,
#      'windSpeedMax80mKTS': 13,
#      'windSpeedMax80mKPH': 25,
#      'windSpeedMax80mMPH': 16,
#      'windSpeedMin80mKTS': 13,
#      'windSpeedMin80mKPH': 25,
#      'windSpeedMin80mMPH': 16,
#      'weather': 'Mostly Sunny',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Sunny',
#      'weatherPrimaryCoded': '::FW',
#      'cloudsCoded': 'FW',
#      'icon': 'pcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568595600,
#      'validTime': '2019-09-16T10:00:00+09:00',
#      'dateTimeISO': '2019-09-16T10:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 75,
#      'minTempC': 24,
#      'minTempF': 75,
#      'avgTempC': 24,
#      'avgTempF': 75,
#      'tempC': 24,
#      'tempF': 75,
#      'pop': 0,
#      'precipMM': 0.03,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 86,
#      'minHumidity': 86,
#      'humidity': 86,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 35,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 25,
#      'feelslikeF': 76,
#      'minFeelslikeC': 25,
#      'minFeelslikeF': 76,
#      'maxFeelslikeC': 25,
#      'maxFeelslikeF': 76,
#      'avgFeelslikeC': 25,
#      'avgFeelslikeF': 76,
#      'dewpointC': 21,
#      'dewpointF': 70,
#      'maxDewpointC': 21,
#      'maxDewpointF': 70,
#      'minDewpointC': 21,
#      'minDewpointF': 70,
#      'avgDewpointC': 21,
#      'avgDewpointF': 70,
#      'windDirDEG': 78,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 78,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 78,
#      'windDirMin': 'ENE',
#      'windGustKTS': 12,
#      'windGustKPH': 22,
#      'windGustMPH': 14,
#      'windSpeedKTS': 12,
#      'windSpeedKPH': 22,
#      'windSpeedMPH': 14,
#      'windSpeedMaxKTS': 12,
#      'windSpeedMaxKPH': 22,
#      'windSpeedMaxMPH': 14,
#      'windSpeedMinKTS': 12,
#      'windSpeedMinKPH': 22,
#      'windSpeedMinMPH': 14,
#      'windDir80mDEG': 80,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 78,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 78,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': 15,
#      'windGust80mKPH': 27,
#      'windGust80mMPH': 17,
#      'windSpeed80mKTS': 15,
#      'windSpeed80mKPH': 27,
#      'windSpeed80mMPH': 17,
#      'windSpeedMax80mKTS': 15,
#      'windSpeedMax80mKPH': 27,
#      'windSpeedMax80mMPH': 17,
#      'windSpeedMin80mKTS': 15,
#      'windSpeedMin80mKPH': 27,
#      'windSpeedMin80mMPH': 17,
#      'weather': 'Partly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Partly Cloudy',
#      'weatherPrimaryCoded': '::SC',
#      'cloudsCoded': 'SC',
#      'icon': 'pcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568599200,
#      'validTime': '2019-09-16T11:00:00+09:00',
#      'dateTimeISO': '2019-09-16T11:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 75,
#      'minTempC': 24,
#      'minTempF': 75,
#      'avgTempC': 24,
#      'avgTempF': 75,
#      'tempC': 24,
#      'tempF': 75,
#      'pop': 0,
#      'precipMM': 0.03,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 86,
#      'minHumidity': 86,
#      'humidity': 86,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 47,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 76,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 76,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 76,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 76,
#      'dewpointC': 21,
#      'dewpointF': 70,
#      'maxDewpointC': 21,
#      'maxDewpointF': 70,
#      'minDewpointC': 21,
#      'minDewpointF': 70,
#      'avgDewpointC': 21,
#      'avgDewpointF': 70,
#      'windDirDEG': 78,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 78,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 78,
#      'windDirMin': 'ENE',
#      'windGustKTS': 13,
#      'windGustKPH': 24,
#      'windGustMPH': 15,
#      'windSpeedKTS': 13,
#      'windSpeedKPH': 24,
#      'windSpeedMPH': 15,
#      'windSpeedMaxKTS': 13,
#      'windSpeedMaxKPH': 24,
#      'windSpeedMaxMPH': 15,
#      'windSpeedMinKTS': 13,
#      'windSpeedMinKPH': 24,
#      'windSpeedMinMPH': 15,
#      'windDir80mDEG': 80,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 78,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 78,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': 16,
#      'windGust80mKPH': 29,
#      'windGust80mMPH': 18,
#      'windSpeed80mKTS': 16,
#      'windSpeed80mKPH': 29,
#      'windSpeed80mMPH': 18,
#      'windSpeedMax80mKTS': 16,
#      'windSpeedMax80mKPH': 29,
#      'windSpeedMax80mMPH': 18,
#      'windSpeedMin80mKTS': 16,
#      'windSpeedMin80mKPH': 29,
#      'windSpeedMin80mMPH': 18,
#      'weather': 'Partly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Partly Cloudy',
#      'weatherPrimaryCoded': '::SC',
#      'cloudsCoded': 'SC',
#      'icon': 'pcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568602800,
#      'validTime': '2019-09-16T12:00:00+09:00',
#      'dateTimeISO': '2019-09-16T12:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 75,
#      'minTempC': 24,
#      'minTempF': 75,
#      'avgTempC': 24,
#      'avgTempF': 75,
#      'tempC': 24,
#      'tempF': 75,
#      'pop': 0,
#      'precipMM': 0.03,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 86,
#      'minHumidity': 86,
#      'humidity': 86,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 60,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 76,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 76,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 76,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 76,
#      'dewpointC': 21,
#      'dewpointF': 70,
#      'maxDewpointC': 21,
#      'maxDewpointF': 70,
#      'minDewpointC': 21,
#      'minDewpointF': 70,
#      'avgDewpointC': 21,
#      'avgDewpointF': 70,
#      'windDirDEG': 78,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 78,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 78,
#      'windDirMin': 'ENE',
#      'windGustKTS': 14,
#      'windGustKPH': 25,
#      'windGustMPH': 16,
#      'windSpeedKTS': 14,
#      'windSpeedKPH': 25,
#      'windSpeedMPH': 16,
#      'windSpeedMaxKTS': 14,
#      'windSpeedMaxKPH': 25,
#      'windSpeedMaxMPH': 16,
#      'windSpeedMinKTS': 14,
#      'windSpeedMinKPH': 25,
#      'windSpeedMinMPH': 16,
#      'windDir80mDEG': 80,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 78,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 78,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': 17,
#      'windGust80mKPH': 32,
#      'windGust80mMPH': 20,
#      'windSpeed80mKTS': 17,
#      'windSpeed80mKPH': 32,
#      'windSpeed80mMPH': 20,
#      'windSpeedMax80mKTS': 17,
#      'windSpeedMax80mKPH': 32,
#      'windSpeedMax80mMPH': 20,
#      'windSpeedMin80mKTS': 17,
#      'windSpeedMin80mKPH': 32,
#      'windSpeedMin80mMPH': 20,
#      'weather': 'Partly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Partly Cloudy',
#      'weatherPrimaryCoded': '::SC',
#      'cloudsCoded': 'SC',
#      'icon': 'pcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568606400,
#      'validTime': '2019-09-16T13:00:00+09:00',
#      'dateTimeISO': '2019-09-16T13:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 74,
#      'minTempC': 24,
#      'minTempF': 74,
#      'avgTempC': 24,
#      'avgTempF': 74,
#      'tempC': 24,
#      'tempF': 74,
#      'pop': 0,
#      'precipMM': 0.02,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 85,
#      'minHumidity': 85,
#      'humidity': 85,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 62,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 76,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 76,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 76,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 76,
#      'dewpointC': 21,
#      'dewpointF': 70,
#      'maxDewpointC': 21,
#      'maxDewpointF': 70,
#      'minDewpointC': 21,
#      'minDewpointF': 70,
#      'avgDewpointC': 21,
#      'avgDewpointF': 70,
#      'windDirDEG': 79,
#      'windDir': 'E',
#      'windDirMaxDEG': 79,
#      'windDirMax': 'E',
#      'windDirMinDEG': 79,
#      'windDirMin': 'E',
#      'windGustKTS': 14,
#      'windGustKPH': 26,
#      'windGustMPH': 16,
#      'windSpeedKTS': 14,
#      'windSpeedKPH': 26,
#      'windSpeedMPH': 16,
#      'windSpeedMaxKTS': 14,
#      'windSpeedMaxKPH': 26,
#      'windSpeedMaxMPH': 16,
#      'windSpeedMinKTS': 14,
#      'windSpeedMinKPH': 26,
#      'windSpeedMinMPH': 16,
#      'windDir80mDEG': 81,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 79,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 79,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 17,
#      'windGust80mKPH': 32,
#      'windGust80mMPH': 20,
#      'windSpeed80mKTS': 17,
#      'windSpeed80mKPH': 32,
#      'windSpeed80mMPH': 20,
#      'windSpeedMax80mKTS': 17,
#      'windSpeedMax80mKPH': 32,
#      'windSpeedMax80mMPH': 20,
#      'windSpeedMin80mKTS': 17,
#      'windSpeedMin80mKPH': 32,
#      'windSpeedMin80mMPH': 20,
#      'weather': 'Partly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Partly Cloudy',
#      'weatherPrimaryCoded': '::SC',
#      'cloudsCoded': 'SC',
#      'icon': 'pcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568610000,
#      'validTime': '2019-09-16T14:00:00+09:00',
#      'dateTimeISO': '2019-09-16T14:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 74,
#      'minTempC': 24,
#      'minTempF': 74,
#      'avgTempC': 24,
#      'avgTempF': 74,
#      'tempC': 24,
#      'tempF': 74,
#      'pop': 0,
#      'precipMM': 0.02,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 84,
#      'minHumidity': 84,
#      'humidity': 84,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 64,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 75,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 75,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 75,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 75,
#      'dewpointC': 21,
#      'dewpointF': 69,
#      'maxDewpointC': 21,
#      'maxDewpointF': 69,
#      'minDewpointC': 21,
#      'minDewpointF': 69,
#      'avgDewpointC': 21,
#      'avgDewpointF': 69,
#      'windDirDEG': 79,
#      'windDir': 'E',
#      'windDirMaxDEG': 79,
#      'windDirMax': 'E',
#      'windDirMinDEG': 79,
#      'windDirMin': 'E',
#      'windGustKTS': 14,
#      'windGustKPH': 26,
#      'windGustMPH': 16,
#      'windSpeedKTS': 14,
#      'windSpeedKPH': 26,
#      'windSpeedMPH': 16,
#      'windSpeedMaxKTS': 14,
#      'windSpeedMaxKPH': 26,
#      'windSpeedMaxMPH': 16,
#      'windSpeedMinKTS': 14,
#      'windSpeedMinKPH': 26,
#      'windSpeedMinMPH': 16,
#      'windDir80mDEG': 81,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 79,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 79,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 17,
#      'windGust80mKPH': 32,
#      'windGust80mMPH': 20,
#      'windSpeed80mKTS': 17,
#      'windSpeed80mKPH': 32,
#      'windSpeed80mMPH': 20,
#      'windSpeedMax80mKTS': 17,
#      'windSpeedMax80mKPH': 32,
#      'windSpeedMax80mMPH': 20,
#      'windSpeedMin80mKTS': 17,
#      'windSpeedMin80mKPH': 32,
#      'windSpeedMin80mMPH': 20,
#      'weather': 'Partly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Partly Cloudy',
#      'weatherPrimaryCoded': '::SC',
#      'cloudsCoded': 'SC',
#      'icon': 'pcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568613600,
#      'validTime': '2019-09-16T15:00:00+09:00',
#      'dateTimeISO': '2019-09-16T15:00:00+09:00',
#      'maxTempC': 23,
#      'maxTempF': 74,
#      'minTempC': 23,
#      'minTempF': 74,
#      'avgTempC': 23,
#      'avgTempF': 74,
#      'tempC': 23,
#      'tempF': 74,
#      'pop': 0,
#      'precipMM': 0.02,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 83,
#      'minHumidity': 83,
#      'humidity': 83,
#      'uvi': 0,
#      'pressureMB': 1013,
#      'pressureIN': 29.91,
#      'sky': 66,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 75,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 75,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 75,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 75,
#      'dewpointC': 20,
#      'dewpointF': 69,
#      'maxDewpointC': 20,
#      'maxDewpointF': 69,
#      'minDewpointC': 20,
#      'minDewpointF': 69,
#      'avgDewpointC': 20,
#      'avgDewpointF': 69,
#      'windDirDEG': 79,
#      'windDir': 'E',
#      'windDirMaxDEG': 79,
#      'windDirMax': 'E',
#      'windDirMinDEG': 79,
#      'windDirMin': 'E',
#      'windGustKTS': 14,
#      'windGustKPH': 27,
#      'windGustMPH': 17,
#      'windSpeedKTS': 14,
#      'windSpeedKPH': 27,
#      'windSpeedMPH': 17,
#      'windSpeedMaxKTS': 14,
#      'windSpeedMaxKPH': 27,
#      'windSpeedMaxMPH': 17,
#      'windSpeedMinKTS': 14,
#      'windSpeedMinKPH': 27,
#      'windSpeedMinMPH': 17,
#      'windDir80mDEG': 81,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 79,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 79,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 17,
#      'windGust80mKPH': 32,
#      'windGust80mMPH': 20,
#      'windSpeed80mKTS': 17,
#      'windSpeed80mKPH': 32,
#      'windSpeed80mMPH': 20,
#      'windSpeedMax80mKTS': 17,
#      'windSpeedMax80mKPH': 32,
#      'windSpeedMax80mMPH': 20,
#      'windSpeedMin80mKTS': 17,
#      'windSpeedMin80mKPH': 32,
#      'windSpeedMin80mMPH': 20,
#      'weather': 'Partly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Partly Cloudy',
#      'weatherPrimaryCoded': '::SC',
#      'cloudsCoded': 'SC',
#      'icon': 'pcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568617200,
#      'validTime': '2019-09-16T16:00:00+09:00',
#      'dateTimeISO': '2019-09-16T16:00:00+09:00',
#      'maxTempC': 23,
#      'maxTempF': 74,
#      'minTempC': 23,
#      'minTempF': 74,
#      'avgTempC': 23,
#      'avgTempF': 74,
#      'tempC': 23,
#      'tempF': 74,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 84,
#      'minHumidity': 84,
#      'humidity': 84,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 73,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 75,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 75,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 75,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 75,
#      'dewpointC': 20,
#      'dewpointF': 69,
#      'maxDewpointC': 20,
#      'maxDewpointF': 69,
#      'minDewpointC': 20,
#      'minDewpointF': 69,
#      'avgDewpointC': 20,
#      'avgDewpointF': 69,
#      'windDirDEG': 79,
#      'windDir': 'E',
#      'windDirMaxDEG': 79,
#      'windDirMax': 'E',
#      'windDirMinDEG': 79,
#      'windDirMin': 'E',
#      'windGustKTS': 14,
#      'windGustKPH': 26,
#      'windGustMPH': 16,
#      'windSpeedKTS': 14,
#      'windSpeedKPH': 26,
#      'windSpeedMPH': 16,
#      'windSpeedMaxKTS': 14,
#      'windSpeedMaxKPH': 26,
#      'windSpeedMaxMPH': 16,
#      'windSpeedMinKTS': 14,
#      'windSpeedMinKPH': 26,
#      'windSpeedMinMPH': 16,
#      'windDir80mDEG': 80,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 79,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 79,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 17,
#      'windGust80mKPH': 32,
#      'windGust80mMPH': 20,
#      'windSpeed80mKTS': 17,
#      'windSpeed80mKPH': 32,
#      'windSpeed80mMPH': 20,
#      'windSpeedMax80mKTS': 17,
#      'windSpeedMax80mKPH': 32,
#      'windSpeedMax80mMPH': 20,
#      'windSpeedMin80mKTS': 17,
#      'windSpeedMin80mKPH': 32,
#      'windSpeedMin80mMPH': 20,
#      'weather': 'Mostly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Cloudy',
#      'weatherPrimaryCoded': '::BK',
#      'cloudsCoded': 'BK',
#      'icon': 'mcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568620800,
#      'validTime': '2019-09-16T17:00:00+09:00',
#      'dateTimeISO': '2019-09-16T17:00:00+09:00',
#      'maxTempC': 23,
#      'maxTempF': 73,
#      'minTempC': 23,
#      'minTempF': 73,
#      'avgTempC': 23,
#      'avgTempF': 73,
#      'tempC': 23,
#      'tempF': 73,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 85,
#      'minHumidity': 85,
#      'humidity': 85,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 80,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 23,
#      'feelslikeF': 74,
#      'minFeelslikeC': 23,
#      'minFeelslikeF': 74,
#      'maxFeelslikeC': 23,
#      'maxFeelslikeF': 74,
#      'avgFeelslikeC': 23,
#      'avgFeelslikeF': 74,
#      'dewpointC': 20,
#      'dewpointF': 68,
#      'maxDewpointC': 20,
#      'maxDewpointF': 68,
#      'minDewpointC': 20,
#      'minDewpointF': 68,
#      'avgDewpointC': 20,
#      'avgDewpointF': 68,
#      'windDirDEG': 79,
#      'windDir': 'E',
#      'windDirMaxDEG': 79,
#      'windDirMax': 'E',
#      'windDirMinDEG': 79,
#      'windDirMin': 'E',
#      'windGustKTS': 13,
#      'windGustKPH': 24,
#      'windGustMPH': 15,
#      'windSpeedKTS': 13,
#      'windSpeedKPH': 24,
#      'windSpeedMPH': 15,
#      'windSpeedMaxKTS': 13,
#      'windSpeedMaxKPH': 24,
#      'windSpeedMaxMPH': 15,
#      'windSpeedMinKTS': 13,
#      'windSpeedMinKPH': 24,
#      'windSpeedMinMPH': 15,
#      'windDir80mDEG': 80,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 79,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 79,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 17,
#      'windGust80mKPH': 31,
#      'windGust80mMPH': 19,
#      'windSpeed80mKTS': 17,
#      'windSpeed80mKPH': 31,
#      'windSpeed80mMPH': 19,
#      'windSpeedMax80mKTS': 17,
#      'windSpeedMax80mKPH': 31,
#      'windSpeedMax80mMPH': 19,
#      'windSpeedMin80mKTS': 17,
#      'windSpeedMin80mKPH': 31,
#      'windSpeedMin80mMPH': 19,
#      'weather': 'Mostly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Cloudy',
#      'weatherPrimaryCoded': '::BK',
#      'cloudsCoded': 'BK',
#      'icon': 'mcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568624400,
#      'validTime': '2019-09-16T18:00:00+09:00',
#      'dateTimeISO': '2019-09-16T18:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 72,
#      'minTempC': 22,
#      'minTempF': 72,
#      'avgTempC': 22,
#      'avgTempF': 72,
#      'tempC': 22,
#      'tempF': 72,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 86,
#      'minHumidity': 86,
#      'humidity': 86,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 86,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 23,
#      'feelslikeF': 73,
#      'minFeelslikeC': 23,
#      'minFeelslikeF': 73,
#      'maxFeelslikeC': 23,
#      'maxFeelslikeF': 73,
#      'avgFeelslikeC': 23,
#      'avgFeelslikeF': 73,
#      'dewpointC': 20,
#      'dewpointF': 68,
#      'maxDewpointC': 20,
#      'maxDewpointF': 68,
#      'minDewpointC': 20,
#      'minDewpointF': 68,
#      'avgDewpointC': 20,
#      'avgDewpointF': 68,
#      'windDirDEG': 79,
#      'windDir': 'E',
#      'windDirMaxDEG': 79,
#      'windDirMax': 'E',
#      'windDirMinDEG': 79,
#      'windDirMin': 'E',
#      'windGustKTS': 13,
#      'windGustKPH': 23,
#      'windGustMPH': 15,
#      'windSpeedKTS': 13,
#      'windSpeedKPH': 23,
#      'windSpeedMPH': 15,
#      'windSpeedMaxKTS': 13,
#      'windSpeedMaxKPH': 23,
#      'windSpeedMaxMPH': 15,
#      'windSpeedMinKTS': 13,
#      'windSpeedMinKPH': 23,
#      'windSpeedMinMPH': 15,
#      'windDir80mDEG': 80,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 79,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 79,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 16,
#      'windGust80mKPH': 30,
#      'windGust80mMPH': 19,
#      'windSpeed80mKTS': 16,
#      'windSpeed80mKPH': 30,
#      'windSpeed80mMPH': 19,
#      'windSpeedMax80mKTS': 16,
#      'windSpeedMax80mKPH': 30,
#      'windSpeedMax80mMPH': 19,
#      'windSpeedMin80mKTS': 16,
#      'windSpeedMin80mKPH': 30,
#      'windSpeedMin80mMPH': 19,
#      'weather': 'Mostly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Cloudy',
#      'weatherPrimaryCoded': '::BK',
#      'cloudsCoded': 'BK',
#      'icon': 'mcloudy.png',
#      'isDay': True},
#     {'timestamp': 1568628000,
#      'validTime': '2019-09-16T19:00:00+09:00',
#      'dateTimeISO': '2019-09-16T19:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 72,
#      'minTempC': 22,
#      'minTempF': 72,
#      'avgTempC': 22,
#      'avgTempF': 72,
#      'tempC': 22,
#      'tempF': 72,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 85,
#      'minHumidity': 85,
#      'humidity': 85,
#      'uvi': 0,
#      'pressureMB': 1015,
#      'pressureIN': 29.97,
#      'sky': 85,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 23,
#      'feelslikeF': 73,
#      'minFeelslikeC': 23,
#      'minFeelslikeF': 73,
#      'maxFeelslikeC': 23,
#      'maxFeelslikeF': 73,
#      'avgFeelslikeC': 23,
#      'avgFeelslikeF': 73,
#      'dewpointC': 20,
#      'dewpointF': 67,
#      'maxDewpointC': 20,
#      'maxDewpointF': 67,
#      'minDewpointC': 20,
#      'minDewpointF': 67,
#      'avgDewpointC': 20,
#      'avgDewpointF': 67,
#      'windDirDEG': 81,
#      'windDir': 'E',
#      'windDirMaxDEG': 81,
#      'windDirMax': 'E',
#      'windDirMinDEG': 81,
#      'windDirMin': 'E',
#      'windGustKTS': 13,
#      'windGustKPH': 25,
#      'windGustMPH': 15,
#      'windSpeedKTS': 13,
#      'windSpeedKPH': 25,
#      'windSpeedMPH': 15,
#      'windSpeedMaxKTS': 13,
#      'windSpeedMaxKPH': 25,
#      'windSpeedMaxMPH': 15,
#      'windSpeedMinKTS': 13,
#      'windSpeedMinKPH': 25,
#      'windSpeedMinMPH': 15,
#      'windDir80mDEG': 82,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 81,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 81,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 18,
#      'windGust80mKPH': 33,
#      'windGust80mMPH': 20,
#      'windSpeed80mKTS': 18,
#      'windSpeed80mKPH': 33,
#      'windSpeed80mMPH': 20,
#      'windSpeedMax80mKTS': 18,
#      'windSpeedMax80mKPH': 33,
#      'windSpeedMax80mMPH': 20,
#      'windSpeedMin80mKTS': 18,
#      'windSpeedMin80mKPH': 33,
#      'windSpeedMin80mMPH': 20,
#      'weather': 'Mostly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Cloudy',
#      'weatherPrimaryCoded': '::BK',
#      'cloudsCoded': 'BK',
#      'icon': 'mcloudyn.png',
#      'isDay': False},
#     {'timestamp': 1568631600,
#      'validTime': '2019-09-16T20:00:00+09:00',
#      'dateTimeISO': '2019-09-16T20:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 72,
#      'minTempC': 22,
#      'minTempF': 72,
#      'avgTempC': 22,
#      'avgTempF': 72,
#      'tempC': 22,
#      'tempF': 72,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 83,
#      'minHumidity': 83,
#      'humidity': 83,
#      'uvi': 0,
#      'pressureMB': 1015,
#      'pressureIN': 29.97,
#      'sky': 83,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 23,
#      'feelslikeF': 73,
#      'minFeelslikeC': 23,
#      'minFeelslikeF': 73,
#      'maxFeelslikeC': 23,
#      'maxFeelslikeF': 73,
#      'avgFeelslikeC': 23,
#      'avgFeelslikeF': 73,
#      'dewpointC': 19,
#      'dewpointF': 67,
#      'maxDewpointC': 19,
#      'maxDewpointF': 67,
#      'minDewpointC': 19,
#      'minDewpointF': 67,
#      'avgDewpointC': 19,
#      'avgDewpointF': 67,
#      'windDirDEG': 81,
#      'windDir': 'E',
#      'windDirMaxDEG': 81,
#      'windDirMax': 'E',
#      'windDirMinDEG': 81,
#      'windDirMin': 'E',
#      'windGustKTS': 14,
#      'windGustKPH': 26,
#      'windGustMPH': 16,
#      'windSpeedKTS': 14,
#      'windSpeedKPH': 26,
#      'windSpeedMPH': 16,
#      'windSpeedMaxKTS': 14,
#      'windSpeedMaxKPH': 26,
#      'windSpeedMaxMPH': 16,
#      'windSpeedMinKTS': 14,
#      'windSpeedMinKPH': 26,
#      'windSpeedMinMPH': 16,
#      'windDir80mDEG': 82,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 81,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 81,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 19,
#      'windGust80mKPH': 35,
#      'windGust80mMPH': 22,
#      'windSpeed80mKTS': 19,
#      'windSpeed80mKPH': 35,
#      'windSpeed80mMPH': 22,
#      'windSpeedMax80mKTS': 19,
#      'windSpeedMax80mKPH': 35,
#      'windSpeedMax80mMPH': 22,
#      'windSpeedMin80mKTS': 19,
#      'windSpeedMin80mKPH': 35,
#      'windSpeedMin80mMPH': 22,
#      'weather': 'Mostly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Cloudy',
#      'weatherPrimaryCoded': '::BK',
#      'cloudsCoded': 'BK',
#      'icon': 'mcloudyn.png',
#      'isDay': False},
#     {'timestamp': 1568635200,
#      'validTime': '2019-09-16T21:00:00+09:00',
#      'dateTimeISO': '2019-09-16T21:00:00+09:00',
#      'maxTempC': 22,
#      'maxTempF': 72,
#      'minTempC': 22,
#      'minTempF': 72,
#      'avgTempC': 22,
#      'avgTempF': 72,
#      'tempC': 22,
#      'tempF': 72,
#      'pop': 0,
#      'precipMM': 0,
#      'precipIN': 0,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 82,
#      'minHumidity': 82,
#      'humidity': 82,
#      'uvi': 0,
#      'pressureMB': 1016,
#      'pressureIN': 30,
#      'sky': 81,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 22,
#      'feelslikeF': 72,
#      'minFeelslikeC': 22,
#      'minFeelslikeF': 72,
#      'maxFeelslikeC': 22,
#      'maxFeelslikeF': 72,
#      'avgFeelslikeC': 22,
#      'avgFeelslikeF': 72,
#      'dewpointC': 19,
#      'dewpointF': 66,
#      'maxDewpointC': 19,
#      'maxDewpointF': 66,
#      'minDewpointC': 19,
#      'minDewpointF': 66,
#      'avgDewpointC': 19,
#      'avgDewpointF': 66,
#      'windDirDEG': 81,
#      'windDir': 'E',
#      'windDirMaxDEG': 81,
#      'windDirMax': 'E',
#      'windDirMinDEG': 81,
#      'windDirMin': 'E',
#      'windGustKTS': 14,
#      'windGustKPH': 27,
#      'windGustMPH': 17,
#      'windSpeedKTS': 14,
#      'windSpeedKPH': 27,
#      'windSpeedMPH': 17,
#      'windSpeedMaxKTS': 14,
#      'windSpeedMaxKPH': 27,
#      'windSpeedMaxMPH': 17,
#      'windSpeedMinKTS': 14,
#      'windSpeedMinKPH': 27,
#      'windSpeedMinMPH': 17,
#      'windDir80mDEG': 82,
#      'windDir80m': 'E',
#      'windDirMax80mDEG': 81,
#      'windDirMax80m': 'E',
#      'windDirMin80mDEG': 81,
#      'windDirMin80m': 'E',
#      'windGust80mKTS': 20,
#      'windGust80mKPH': 37,
#      'windGust80mMPH': 23,
#      'windSpeed80mKTS': 20,
#      'windSpeed80mKPH': 37,
#      'windSpeed80mMPH': 23,
#      'windSpeedMax80mKTS': 20,
#      'windSpeedMax80mKPH': 37,
#      'windSpeedMax80mMPH': 23,
#      'windSpeedMin80mKTS': 20,
#      'windSpeedMin80mKPH': 37,
#      'windSpeedMin80mMPH': 23,
#      'weather': 'Mostly Cloudy',
#      'weatherCoded': [],
#      'weatherPrimary': 'Mostly Cloudy',
#      'weatherPrimaryCoded': '::BK',
# ...
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 84,
#      'minHumidity': 84,
#      'humidity': 84,
#      'uvi': 0,
#      'pressureMB': 1016,
#      'pressureIN': 30,
#      'sky': 89,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 75,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 75,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 75,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 75,
#      'dewpointC': 21,
#      'dewpointF': 69,
#      'maxDewpointC': 21,
#      'maxDewpointF': 69,
#      'minDewpointC': 21,
#      'minDewpointF': 69,
#      'avgDewpointC': 21,
#      'avgDewpointF': 69,
#      'windDirDEG': 73,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 73,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 73,
#      'windDirMin': 'ENE',
#      'windGustKTS': 23,
#      'windGustKPH': 43,
#      'windGustMPH': 27,
#      'windSpeedKTS': 23,
#      'windSpeedKPH': 43,
#      'windSpeedMPH': 27,
#      'windSpeedMaxKTS': 23,
#      'windSpeedMaxKPH': 43,
#      'windSpeedMaxMPH': 27,
#      'windSpeedMinKTS': 23,
#      'windSpeedMinKPH': 43,
#      'windSpeedMinMPH': 27,
#      'windDir80mDEG': None,
#      'windDir80m': None,
#      'windDirMax80mDEG': 73,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 73,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': None,
#      'windGust80mKPH': None,
#      'windGust80mMPH': None,
#      'windSpeed80mKTS': None,
#      'windSpeed80mKPH': None,
#      'windSpeed80mMPH': None,
#      'windSpeedMax80mKTS': None,
#      'windSpeedMax80mKPH': None,
#      'windSpeedMax80mMPH': None,
#      'windSpeedMin80mKTS': None,
#      'windSpeedMin80mKPH': None,
#      'windSpeedMin80mMPH': None,
#      'weather': 'Mostly Cloudy with Light Rain',
#      'weatherCoded': [{'timestamp': 1569196800,
#        'wx': ':L:R',
#        'dateTimeISO': '2019-09-23T09:00:00+09:00'}],
#      'weatherPrimary': 'Light Rain',
#      'weatherPrimaryCoded': ':L:R',
#      'cloudsCoded': 'BK',
#      'icon': 'rain.png',
#      'isDay': True},
#     {'timestamp': 1569200400,
#      'validTime': '2019-09-23T10:00:00+09:00',
#      'dateTimeISO': '2019-09-23T10:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 74,
#      'minTempC': 24,
#      'minTempF': 74,
#      'avgTempC': 24,
#      'avgTempF': 74,
#      'tempC': 24,
#      'tempF': 74,
#      'pop': 25,
#      'precipMM': 0.62,
#      'precipIN': 0.02,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 84,
#      'minHumidity': 84,
#      'humidity': 84,
#      'uvi': 0,
#      'pressureMB': 1015,
#      'pressureIN': 29.97,
#      'sky': 89,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 75,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 75,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 75,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 75,
#      'dewpointC': 21,
#      'dewpointF': 69,
#      'maxDewpointC': 21,
#      'maxDewpointF': 69,
#      'minDewpointC': 21,
#      'minDewpointF': 69,
#      'avgDewpointC': 21,
#      'avgDewpointF': 69,
#      'windDirDEG': 78,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 78,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 78,
#      'windDirMin': 'ENE',
#      'windGustKTS': 23,
#      'windGustKPH': 43,
#      'windGustMPH': 26,
#      'windSpeedKTS': 23,
#      'windSpeedKPH': 43,
#      'windSpeedMPH': 26,
#      'windSpeedMaxKTS': 23,
#      'windSpeedMaxKPH': 43,
#      'windSpeedMaxMPH': 26,
#      'windSpeedMinKTS': 23,
#      'windSpeedMinKPH': 43,
#      'windSpeedMinMPH': 26,
#      'windDir80mDEG': None,
#      'windDir80m': None,
#      'windDirMax80mDEG': 78,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 78,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': None,
#      'windGust80mKPH': None,
#      'windGust80mMPH': None,
#      'windSpeed80mKTS': None,
#      'windSpeed80mKPH': None,
#      'windSpeed80mMPH': None,
#      'windSpeedMax80mKTS': None,
#      'windSpeedMax80mKPH': None,
#      'windSpeedMax80mMPH': None,
#      'windSpeedMin80mKTS': None,
#      'windSpeedMin80mKPH': None,
#      'windSpeedMin80mMPH': None,
#      'weather': 'Mostly Cloudy with Light Rain',
#      'weatherCoded': [{'timestamp': 1569200400,
#        'wx': ':L:R',
#        'dateTimeISO': '2019-09-23T10:00:00+09:00'}],
#      'weatherPrimary': 'Light Rain',
#      'weatherPrimaryCoded': ':L:R',
#      'cloudsCoded': 'BK',
#      'icon': 'rain.png',
#      'isDay': True},
#     {'timestamp': 1569204000,
#      'validTime': '2019-09-23T11:00:00+09:00',
#      'dateTimeISO': '2019-09-23T11:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 74,
#      'minTempC': 24,
#      'minTempF': 74,
#      'avgTempC': 24,
#      'avgTempF': 74,
#      'tempC': 24,
#      'tempF': 74,
#      'pop': 25,
#      'precipMM': 0.62,
#      'precipIN': 0.02,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 84,
#      'minHumidity': 84,
#      'humidity': 84,
#      'uvi': 0,
#      'pressureMB': 1015,
#      'pressureIN': 29.97,
#      'sky': 88,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 75,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 75,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 75,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 75,
#      'dewpointC': 21,
#      'dewpointF': 69,
#      'maxDewpointC': 21,
#      'maxDewpointF': 69,
#      'minDewpointC': 21,
#      'minDewpointF': 69,
#      'avgDewpointC': 21,
#      'avgDewpointF': 69,
#      'windDirDEG': 78,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 78,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 78,
#      'windDirMin': 'ENE',
#      'windGustKTS': 23,
#      'windGustKPH': 42,
#      'windGustMPH': 26,
#      'windSpeedKTS': 23,
#      'windSpeedKPH': 42,
#      'windSpeedMPH': 26,
#      'windSpeedMaxKTS': 23,
#      'windSpeedMaxKPH': 42,
#      'windSpeedMaxMPH': 26,
#      'windSpeedMinKTS': 23,
#      'windSpeedMinKPH': 42,
#      'windSpeedMinMPH': 26,
#      'windDir80mDEG': None,
#      'windDir80m': None,
#      'windDirMax80mDEG': 78,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 78,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': None,
#      'windGust80mKPH': None,
#      'windGust80mMPH': None,
#      'windSpeed80mKTS': None,
#      'windSpeed80mKPH': None,
#      'windSpeed80mMPH': None,
#      'windSpeedMax80mKTS': None,
#      'windSpeedMax80mKPH': None,
#      'windSpeedMax80mMPH': None,
#      'windSpeedMin80mKTS': None,
#      'windSpeedMin80mKPH': None,
#      'windSpeedMin80mMPH': None,
#      'weather': 'Mostly Cloudy with Light Rain',
#      'weatherCoded': [{'timestamp': 1569204000,
#        'wx': ':L:R',
#        'dateTimeISO': '2019-09-23T11:00:00+09:00'}],
#      'weatherPrimary': 'Light Rain',
#      'weatherPrimaryCoded': ':L:R',
#      'cloudsCoded': 'BK',
#      'icon': 'rain.png',
#      'isDay': True},
#     {'timestamp': 1569207600,
#      'validTime': '2019-09-23T12:00:00+09:00',
#      'dateTimeISO': '2019-09-23T12:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 74,
#      'minTempC': 24,
#      'minTempF': 74,
#      'avgTempC': 24,
#      'avgTempF': 74,
#      'tempC': 24,
#      'tempF': 74,
#      'pop': 25,
#      'precipMM': 0.62,
#      'precipIN': 0.02,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 84,
#      'minHumidity': 84,
#      'humidity': 84,
#      'uvi': 0,
#      'pressureMB': 1015,
#      'pressureIN': 29.97,
#      'sky': 87,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 75,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 75,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 75,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 75,
#      'dewpointC': 21,
#      'dewpointF': 69,
#      'maxDewpointC': 21,
#      'maxDewpointF': 69,
#      'minDewpointC': 21,
#      'minDewpointF': 69,
#      'avgDewpointC': 21,
#      'avgDewpointF': 69,
#      'windDirDEG': 78,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 78,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 78,
#      'windDirMin': 'ENE',
#      'windGustKTS': 23,
#      'windGustKPH': 42,
#      'windGustMPH': 26,
#      'windSpeedKTS': 23,
#      'windSpeedKPH': 42,
#      'windSpeedMPH': 26,
#      'windSpeedMaxKTS': 23,
#      'windSpeedMaxKPH': 42,
#      'windSpeedMaxMPH': 26,
#      'windSpeedMinKTS': 23,
#      'windSpeedMinKPH': 42,
#      'windSpeedMinMPH': 26,
#      'windDir80mDEG': None,
#      'windDir80m': None,
#      'windDirMax80mDEG': 78,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 78,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': None,
#      'windGust80mKPH': None,
#      'windGust80mMPH': None,
#      'windSpeed80mKTS': None,
#      'windSpeed80mKPH': None,
#      'windSpeed80mMPH': None,
#      'windSpeedMax80mKTS': None,
#      'windSpeedMax80mKPH': None,
#      'windSpeedMax80mMPH': None,
#      'windSpeedMin80mKTS': None,
#      'windSpeedMin80mKPH': None,
#      'windSpeedMin80mMPH': None,
#      'weather': 'Mostly Cloudy with Light Rain',
#      'weatherCoded': [{'timestamp': 1569207600,
#        'wx': ':L:R',
#        'dateTimeISO': '2019-09-23T12:00:00+09:00'}],
#      'weatherPrimary': 'Light Rain',
#      'weatherPrimaryCoded': ':L:R',
#      'cloudsCoded': 'BK',
#      'icon': 'rain.png',
#      'isDay': True},
#     {'timestamp': 1569211200,
#      'validTime': '2019-09-23T13:00:00+09:00',
#      'dateTimeISO': '2019-09-23T13:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 74,
#      'minTempC': 24,
#      'minTempF': 74,
#      'avgTempC': 24,
#      'avgTempF': 74,
#      'tempC': 24,
#      'tempF': 74,
#      'pop': 25,
#      'precipMM': 0.62,
#      'precipIN': 0.02,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 84,
#      'minHumidity': 84,
#      'humidity': 84,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 86,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 76,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 76,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 76,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 76,
#      'dewpointC': 21,
#      'dewpointF': 69,
#      'maxDewpointC': 21,
#      'maxDewpointF': 69,
#      'minDewpointC': 21,
#      'minDewpointF': 69,
#      'avgDewpointC': 21,
#      'avgDewpointF': 69,
#      'windDirDEG': 78,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 78,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 78,
#      'windDirMin': 'ENE',
#      'windGustKTS': 23,
#      'windGustKPH': 42,
#      'windGustMPH': 26,
#      'windSpeedKTS': 23,
#      'windSpeedKPH': 42,
#      'windSpeedMPH': 26,
#      'windSpeedMaxKTS': 23,
#      'windSpeedMaxKPH': 42,
#      'windSpeedMaxMPH': 26,
#      'windSpeedMinKTS': 23,
#      'windSpeedMinKPH': 42,
#      'windSpeedMinMPH': 26,
#      'windDir80mDEG': None,
#      'windDir80m': None,
#      'windDirMax80mDEG': 78,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 78,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': None,
#      'windGust80mKPH': None,
#      'windGust80mMPH': None,
#      'windSpeed80mKTS': None,
#      'windSpeed80mKPH': None,
#      'windSpeed80mMPH': None,
#      'windSpeedMax80mKTS': None,
#      'windSpeedMax80mKPH': None,
#      'windSpeedMax80mMPH': None,
#      'windSpeedMin80mKTS': None,
#      'windSpeedMin80mKPH': None,
#      'windSpeedMin80mMPH': None,
#      'weather': 'Mostly Cloudy with Light Rain',
#      'weatherCoded': [{'timestamp': 1569211200,
#        'wx': ':L:R',
#        'dateTimeISO': '2019-09-23T13:00:00+09:00'}],
#      'weatherPrimary': 'Light Rain',
#      'weatherPrimaryCoded': ':L:R',
#      'cloudsCoded': 'BK',
#      'icon': 'rain.png',
#      'isDay': True},
#     {'timestamp': 1569214800,
#      'validTime': '2019-09-23T14:00:00+09:00',
#      'dateTimeISO': '2019-09-23T14:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 74,
#      'minTempC': 24,
#      'minTempF': 74,
#      'avgTempC': 24,
#      'avgTempF': 74,
#      'tempC': 24,
#      'tempF': 74,
#      'pop': 25,
#      'precipMM': 0.62,
#      'precipIN': 0.02,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 84,
#      'minHumidity': 84,
#      'humidity': 84,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 85,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 76,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 76,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 76,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 76,
#      'dewpointC': 21,
#      'dewpointF': 69,
#      'maxDewpointC': 21,
#      'maxDewpointF': 69,
#      'minDewpointC': 21,
#      'minDewpointF': 69,
#      'avgDewpointC': 21,
#      'avgDewpointF': 69,
#      'windDirDEG': 78,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 78,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 78,
#      'windDirMin': 'ENE',
#      'windGustKTS': 23,
#      'windGustKPH': 42,
#      'windGustMPH': 26,
#      'windSpeedKTS': 23,
#      'windSpeedKPH': 42,
#      'windSpeedMPH': 26,
#      'windSpeedMaxKTS': 23,
#      'windSpeedMaxKPH': 42,
#      'windSpeedMaxMPH': 26,
#      'windSpeedMinKTS': 23,
#      'windSpeedMinKPH': 42,
#      'windSpeedMinMPH': 26,
#      'windDir80mDEG': None,
#      'windDir80m': None,
#      'windDirMax80mDEG': 78,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 78,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': None,
#      'windGust80mKPH': None,
#      'windGust80mMPH': None,
#      'windSpeed80mKTS': None,
#      'windSpeed80mKPH': None,
#      'windSpeed80mMPH': None,
#      'windSpeedMax80mKTS': None,
#      'windSpeedMax80mKPH': None,
#      'windSpeedMax80mMPH': None,
#      'windSpeedMin80mKTS': None,
#      'windSpeedMin80mKPH': None,
#      'windSpeedMin80mMPH': None,
#      'weather': 'Mostly Cloudy with Light Rain',
#      'weatherCoded': [{'timestamp': 1569214800,
#        'wx': ':L:R',
#        'dateTimeISO': '2019-09-23T14:00:00+09:00'}],
#      'weatherPrimary': 'Light Rain',
#      'weatherPrimaryCoded': ':L:R',
#      'cloudsCoded': 'BK',
#      'icon': 'rain.png',
#      'isDay': True},
#     {'timestamp': 1569218400,
#      'validTime': '2019-09-23T15:00:00+09:00',
#      'dateTimeISO': '2019-09-23T15:00:00+09:00',
#      'maxTempC': 24,
#      'maxTempF': 74,
#      'minTempC': 24,
#      'minTempF': 74,
#      'avgTempC': 24,
#      'avgTempF': 74,
#      'tempC': 24,
#      'tempF': 74,
#      'pop': 25,
#      'precipMM': 0.62,
#      'precipIN': 0.02,
#      'iceaccum': None,
#      'iceaccumMM': None,
#      'iceaccumIN': None,
#      'maxHumidity': 84,
#      'minHumidity': 84,
#      'humidity': 84,
#      'uvi': 0,
#      'pressureMB': 1014,
#      'pressureIN': 29.94,
#      'sky': 84,
#      'snowCM': 0,
#      'snowIN': 0,
#      'feelslikeC': 24,
#      'feelslikeF': 76,
#      'minFeelslikeC': 24,
#      'minFeelslikeF': 76,
#      'maxFeelslikeC': 24,
#      'maxFeelslikeF': 76,
#      'avgFeelslikeC': 24,
#      'avgFeelslikeF': 76,
#      'dewpointC': 21,
#      'dewpointF': 69,
#      'maxDewpointC': 21,
#      'maxDewpointF': 69,
#      'minDewpointC': 21,
#      'minDewpointF': 69,
#      'avgDewpointC': 21,
#      'avgDewpointF': 69,
#      'windDirDEG': 78,
#      'windDir': 'ENE',
#      'windDirMaxDEG': 78,
#      'windDirMax': 'ENE',
#      'windDirMinDEG': 78,
#      'windDirMin': 'ENE',
#      'windGustKTS': 23,
#      'windGustKPH': 42,
#      'windGustMPH': 26,
#      'windSpeedKTS': 23,
#      'windSpeedKPH': 42,
#      'windSpeedMPH': 26,
#      'windSpeedMaxKTS': 23,
#      'windSpeedMaxKPH': 42,
#      'windSpeedMaxMPH': 26,
#      'windSpeedMinKTS': 23,
#      'windSpeedMinKPH': 42,
#      'windSpeedMinMPH': 26,
#      'windDir80mDEG': None,
#      'windDir80m': None,
#      'windDirMax80mDEG': 78,
#      'windDirMax80m': 'ENE',
#      'windDirMin80mDEG': 78,
#      'windDirMin80m': 'ENE',
#      'windGust80mKTS': None,
#      'windGust80mKPH': None,
#      'windGust80mMPH': None,
#      'windSpeed80mKTS': None,
#      'windSpeed80mKPH': None,
#      'windSpeed80mMPH': None,
#      'windSpeedMax80mKTS': None,
#      'windSpeedMax80mKPH': None,
#      'windSpeedMax80mMPH': None,
#      'windSpeedMin80mKTS': None,
#      'windSpeedMin80mKPH': None,
#      'windSpeedMin80mMPH': None,
#      'weather': 'Mostly Cloudy with Light Rain',
#      'weatherCoded': [{'timestamp': 1569218400,
#        'wx': ':L:R',
#        'dateTimeISO': '2019-09-23T15:00:00+09:00'}],
#      'weatherPrimary': 'Light Rain',
#      'weatherPrimaryCoded': ':L:R',
#      'cloudsCoded': 'BK',
#      'icon': 'rain.png',
#      'isDay': True}],
#    'profile': {'tz': 'Asia/Seoul'}}]}

# %%
#날씨 csv 저장
def storeWeather():
    weather=pd.DataFrame(columns=['SDT_YY', 'SDT_MM', 'SDT_DD','hour','ARP','temp', 'hum', 'dew', 'windSpeed','hpa'])

    for i in range(15):
        area=["seoul","busan","jeju","daegu","ulsan","cheongju","muan","gwangju","yeosu"
              ,"yangyang","pohang","sacheon","gunsan","wonju","incheon"]
        d=readJSON(area[i])
        response=d['response'][0]
        data=response['periods']
    
    
        for j in range(len(data)):
            temp=data[j]
            date=dateutil.parser.parse(temp['dateTimeISO'])
            temp2=pd.Series([date.year,date.month,date.day,date.hour,"ARP"+str(i+1),temp['tempC'],
                         temp['humidity'],temp['dewpointC'],temp['windGustKTS'],temp['pressureMB']],
                        index=['SDT_YY', 'SDT_MM', 'SDT_DD','hour','ARP','temp', 'hum', 'dew', 'windSpeed','hpa'])
        
            weather=weather.append(temp2,ignore_index=True)
    
    #fog 모델하고의 단위 맞추는 작업
    weather['windSpeed']=weather['windSpeed'].astype("float")*1852/3600
    
    weather.to_csv("newWeather.csv",index=False)

# %%
#미래 날씨 데이터 합치기

from datetime import datetime
now=datetime.now()
if now.day>=16:
    we=pd.read_csv('newWeather.csv', encoding="cp949")
    
else:
    print(now.day)
    storeWeather()
    we=pd.read_csv('newWeather.csv', encoding="cp949")
# Out:
# 8

# %%
final= pd.merge(we, dly, on=['SDT_YY', 'SDT_MM', 'SDT_DD', 'ARP','hour'])
final

#---------------------------------------
# Out:
#       SDT_YY  SDT_MM  SDT_DD  hour    ARP  temp  hum  dew  windSpeed   hpa  \
# 0       2019       9      16     6   ARP1    22   69   16   1.028889  1015
# 1       2019       9      16     6   ARP1    22   69   16   1.028889  1015
# 2       2019       9      16     6   ARP1    22   69   16   1.028889  1015
# 3       2019       9      16     6   ARP1    22   69   16   1.028889  1015
# 4       2019       9      16     6   ARP1    22   69   16   1.028889  1015
# ...      ...     ...     ...   ...    ...   ...  ...  ...        ...   ...
# 8129    2019       9      23     8  ARP15    18   76   13   4.115556  1020
# 8130    2019       9      23     8  ARP15    18   76   13   4.115556  1020
# 8131    2019       9      23     8  ARP15    18   76   13   4.115556  1020
# 8132    2019       9      23    11  ARP15    21   66   14   4.115556  1019
# 8133    2019       9      23    14  ARP15    24   54   14   4.115556  1018
#
#      SDT_DY    ODP FLO    FLT AOD    STT  DLY  DLY_RATE
# 0         월   ARP3   L  L1701   D   6:40  NaN       NaN
# 1         월  ARP12   J  J1634   D   6:50  NaN       NaN
# 2         월   ARP3   F  F1201   D   6:10  NaN       NaN
# 3         월   ARP3   F  F1203   D   6:15  NaN       NaN
# 4         월   ARP3   J  J1204   D   6:20  NaN       NaN
# ...     ...    ...  ..    ...  ..    ...  ...       ...
# 8129      월   ARP2   J  J1404   D   8:25  NaN       NaN
# 8130      월   ARP2   J  J1405   A   8:10  NaN       NaN
# 8131      월   ARP4   J  J1413   A   8:05  NaN       NaN
# 8132      월   ARP2   J  J1407   A  11:55  NaN       NaN
# 8133      월   ARP2   J  J1409   A  14:35  NaN       NaN
#
# [8134 rows x 18 columns]

# %%
# 파생변수
final['ARPODP'] = final['ARP'] + '_' + final['ODP']

# %%
# 필요없는 column 제거
final.drop(columns=['FLT', 'DLY', 'DLY_RATE'], axis=1, inplace=True)

# %%
# 시간 + 분 합침.
final['time']= (pd.to_datetime(final['STT'],format= '%H:%M').dt.hour).astype(str) + (pd.to_datetime(final['STT'],format= '%H:%M').dt.minute).astype(str)

#dly 스케일링
from sklearn.preprocessing import MinMaxScaler
final['time']= final['time'].astype('int')
scaler = MinMaxScaler()
final[['time']] = scaler.fit_transform(final[['time']])


#예정시각 삭제
final.drop(['STT'], axis = 1, inplace=True)

# %%
import warnings
warnings.filterwarnings(action="ignore")

for i in range(5):
    day= dly[dly['SDT_DD']==26+i]
    
    temps=[]
    hums=[]
    dews=[]
    winds=[]

    for j in range(len(day)):
        prev_5= we[ (we['ARP']==day.iloc[j]['ARP']) & (we['hour']==day.iloc[j]['hour']) & 
                      (we['SDT_DD'] >= 26+i-5) & (we['SDT_DD'] < 26+i) ]        
        print('prevs', prev_5)
        temp=0.0
        hum=0.0
        dew=0.0
        windSpeed=0.0

        for k in range(len(prev_5)):
            temp += prev_5.iloc[k]['temp']
            hum += prev_5.iloc[k]['hum']
            dew += prev_5.iloc[k]['dew']
            windSpeed += prev_5.iloc[k]['windSpeed']
        
        print(temp, hum, dew, windSpeed)
        
        if temp > 0:
            temp= temp / len(prev_5)
        if hum > 0:
            hum= hum / len(prev_5)
        if dew > 0:
            dew= dew / len(prev_5)
        if windSpeed > 0:
            windSpeed= windSpeed / len(prev_5)
        
        temps.append(temp)
        hums.append(hum)
        dews.append(dews)
        winds.append(windSpeed)

    
#    print(len(temps), len(hums), len(dews), len(winds))

    day['temp']= temps
    day['hum']=hums
    day['dew']=dews
    day['windSpeed']=winds

    print(day)

    final= final.append(day)

# %%
print(final.tail())
final[final['SDT_DD']==26]

# %%
from sklearn import preprocessing
# DLY도 1과 0으로 데이터 처리
le = preprocessing.LabelEncoder()
final[['ARP']] = le.fit_transform(final[['ARP']])
final[['ODP']] = le.fit_transform(final[['ODP']])
final[['FLO']] = le.fit_transform(final[['FLO']])
final[['ARPODP']] = le.fit_transform(final[['ARPODP']])

# %%
## Todo: 요일은 계속 원핫???
one_hot_dy = pd.get_dummies(final['SDT_DY'])
final = final.drop(['SDT_DY'],axis = 1)
final = final.join(one_hot_dy)
final.rename(columns={"일":"Sun","월":"Mon","화":"Tue","수":"Wed","목":"Thu","금":"Fri","토":"SAT","일":"Sun"                    
                  }, inplace=True)

# %%
# YY랑 DD삭제
final.drop(columns=['SDT_YY', 'SDT_DD'], axis=1, inplace=True)

# %%
final.columns

final.drop(columns=['hour'], axis=1, inplace=True)

# 중요도 낮은 변수들 제거

# %%
from sklearn.preprocessing import RobustScaler
import pickle
from sklearn.externals import joblib

def fogModel(df):
    # 날씨 missing 값들은 0으로 대체
    df.fillna(0, inplace = True)
    
    # 모델에서 쓰인 Scaling기법 적용
    scaler = RobustScaler()
    df[['hum', 'dew','temp','windSpeed']] = scaler.fit_transform(df[['hum', 'dew','temp','windSpeed']])
    
    # 저장된 모델 불러오기
    clf_from_joblib = joblib.load('fogmodel.pkl') 

    # 지연 율 저장
    fog_prob = clf_from_joblib.predict_proba(df)
    

    fog_column = []
    # dly_rate에 지연율 저장
    for i in fog_prob:
        fog_column.append(i[1])
        
    
    return fog_column

# %%
# df에서 fog관련 column만 함수에 넘김
fog = final[["temp","hum","dew","windSpeed"]]

fog_column = fogModel(fog)

# %%
# 안개 column 추가
final['fog'] = fog_column

# 안개 관련 column 제거
final.drop(columns=['hum', 'dew','temp','windSpeed'], axis=1, inplace=True)
final.head()

# %%
# 도착, 출발 데이터 분리
final_A = final[final['AOD']=='A']
final_D = final[final['AOD']=='D']

# AOD column삭제 
final_A = final_A.drop(['AOD'],axis = 1)
final_D = final_D.drop(['AOD'],axis = 1)

# %%
(final_A.columns)

# %%
# ------------------------------ #

# %%
########## 아직 저장된 모델이 없음

# df_A 모델 -----------------------------------------------

# df_A 모델 불러오기
predict_dealy_A_joblib = joblib.load('predict_delay_A.pkl') 

# DLY 저장하기
dly_A = predict_dealy_A_joblib.predict(final_A)

# DLY_RATE 저장하기
dly_A_prob = predict_dealy_A_joblib.predict_proba(final_A)

dly_rate_A = []

# dly_rate에 지연율 저장
for i in dly_A_prob:
    dly_rate_A.append(i[1])
    
# DateFrame에 DLY, DLY_RATE추가
final.loc[dly['AOD']=='A','DLY'] = dly_A
final.loc[dly['AOD']=='A','DLY_RATE'] = dly_rate_A

# ---------------------------------------------------------

# %%
# df_D 모델 -----------------------------------------------

# df_D 모델 불러오기
predict_dealy_D_joblib = joblib.load('predict_delay_D.pkl') 

# DLY 저장하기
dly_D = predict_dealy_D_joblib.predict(df_D)

# DLY_RATE 저장하기
dly_A_prob = predict_dealy_A_joblib.predict_proba(df_D)

dly_rate_D = []

# dly_rate에 지연율 저장
for i in dly_D_prob:
    dly_rate_D.append(i[1])
    
# DateFrame에 DLY, DLY_RATE추가
final.loc[dly['AOD']=='D','DLY'] = dly_D
final.loc[dly['AOD']=='D','DLY_RATE'] = dly_rate_D

# ---------------------------------------------------------

# %%
# 라벨을 1,0에서 -> Y,N으로 
final.loc[dly['DLY']==1,'DLY'] = 'Y'
final.loc[dly['DLY']==0,'DLY'] = 'N'
